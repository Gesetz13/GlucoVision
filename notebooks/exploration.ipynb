# %%
print("Ba Koko!")
# Out:
# Ba Koko!

# %%
import os
import pandas as pd

# Pfad zur Parquet-Datei im übergeordneten Ordner ../data
data_path = os.path.join("..", "data", "phoenix_anonymized.parquet")

# Daten einlesen
df = pd.read_parquet(data_path)

# %%
df.head()
# Out:
#    Unnamed: 0    DeviceId  IsControlSolutionDetected MeasurementStatus  \
# 0           0  A101001231                      False         NOT_RATED
# 1           1  A101001282                      False         NOT_RATED
# 2           2  A101001282                      False         NOT_RATED
# 3           3  A101001282                      False         NOT_RATED
# 4           4  A101001286                      False         NOT_RATED
#
#    IsEmergencyTest                                          PatientId  \
# 0            False  jJHgdIcpnQHTwM08jD1w6oCiv8r+f1r4ZhLxIdDstXf+uh...
# 1            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 2            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 3            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 4            False  1z9/QVfYDgJsrkRIy8J43zxvckyonbJk2uizzFKVpknR+p...
#
#        ResultUnit  IsResultValueTooHigh  IsResultValueTooLow  StripId  ...  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0       StripId  InstrumentLotId  PrivacyLevel  \
# count  2.402642e+06  2.402642e+06     2.402642e+06  2.402642e+06
# mean   1.201320e+06  1.591106e+03     5.255331e+06  2.999813e+00
# min    0.000000e+00  1.106000e+03     5.111262e+06  1.000000e+00
# 25%    6.006602e+05  1.558000e+03     5.211071e+06  3.000000e+00
# 50%    1.201320e+06  1.654000e+03     5.211181e+06  3.000000e+00
# 75%    1.801981e+06  1.675000e+03     5.304171e+06  3.000000e+00
# max    2.402641e+06  1.828000e+03     5.411111e+06  3.000000e+00
# std    6.935831e+05  1.340675e+02     7.801848e+04  1.372981e-02
#
#                            Timestamp  TimeSinceLast  GlucoseValue
# count                        2402642   2.016591e+06  2.402642e+06
# mean   2024-07-01 20:58:12.383372288   1.775979e+04  1.290769e+02
# min              2021-10-12 21:13:06  -5.896059e+07  6.000000e-01
# 25%       2024-04-18 07:51:10.500000  -3.026806e+06  7.800000e+01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2402642 entries, 0 to 2402641
# Data columns (total 21 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Unnamed: 0                 int64
#  1   DeviceId                   object
#  2   IsControlSolutionDetected  bool
#  3   MeasurementStatus          object
#  4   IsEmergencyTest            bool
#  5   PatientId                  object
#  6   ResultUnit                 object
#  7   IsResultValueTooHigh       bool
#  8   IsResultValueTooLow        bool
#  9   StripId                    int64
#  10  ShipToAccountId            object
#  11  InstrumentLotId            int64
#  12  Location                   object
#  13  PrivacyLevel               int64
#  14  PatientID                  object
#  15  Institution                object
#  16  Timestamp                  datetime64[ns]
#  17  TimeSinceLast              float64
#  18  Region                     object
# ...

# %%
df["PatientID"].value_counts().describe()
# Out:
# count    386051.000000
# mean          6.223639
# std          25.647652
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           3.000000
# max        4921.000000
# Name: count, dtype: float64

# %%
# Patienten mit mind. 6 Messungen
valid_patients = df["PatientID"].value_counts()
valid_patients = valid_patients[valid_patients >= 6].index

df_rnn = df[df["PatientID"].isin(valid_patients)].copy()

# %%
df_rnn.head()
# Out:
#    Unnamed: 0    DeviceId  IsControlSolutionDetected MeasurementStatus  \
# 1           1  A101001282                      False         NOT_RATED
# 2           2  A101001282                      False         NOT_RATED
# 3           3  A101001282                      False         NOT_RATED
# 5           5  A101001286                      False         NOT_RATED
# 6           6  A101001286                      False         NOT_RATED
#
#    IsEmergencyTest                                          PatientId  \
# 1            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 2            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 3            False  nf4tBdCwGSjlN2UNcyrRXfVzxdEG3dxlZ2NYNKW3c9ChqX...
# 5            False  BIr2Iq66c8+qykriWxoEWZOb7gH2ULb/8VxEOzqCajHJpG...
# 6            False  BIr2Iq66c8+qykriWxoEWZOb7gH2ULb/8VxEOzqCajHJpG...
#
#        ResultUnit  IsResultValueTooHigh  IsResultValueTooLow  StripId  ...  \
# ...
